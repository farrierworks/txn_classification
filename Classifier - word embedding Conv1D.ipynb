# %%
#import statements
import pandas as pd
import numpy as np
import time
import os

# %%
import spacy

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.text import Tokenizer



import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
df1 = pd.read_csv('input_data_base.csv', index_col = 0)

# %%
df2 = df1[['GL', 'Reduction text']].copy()

# %%
import spacy
nlp = spacy.load('en_vectors_web_lg')
def similarityy(x,y):
    return(nlp(x).similarity(nlp(y)))

def sim_comp(col,word):
    out = []
    col = list(col)
    for entry in col:
        out.append(similarityy(entry,word))
    return(out)

#remove "non words" such as SKU numbers
for i in range(1, len(df2)+1):
    try:
        if similarityy(df2['Reduction text'][i],'tool')==0:
            df2.drop(i, inplace = True)    
    except:
        pass
    
#warning, really annoying output from "zero vector word comparisons"
# Out:
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
# c:\users\olfoa\appdata\local\programs\python\python36\lib\runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
# ...

# %%
#balance the data by GL
working_data = df2
working_data.groupby('GL').count()
entries = min(list(working_data.groupby('GL').count()['Reduction text']))
balanced_GLs = []
index_list = list(working_data.groupby('GL').count().index)
for GL in index_list:
    balanced_GLs.append(working_data[working_data['GL']==GL].sample(entries))

balanced_data = pd.concat(balanced_GLs,axis = 0, ignore_index = True)

# %%
text = balanced_data['Reduction text'].tolist()

# %%
token = Tokenizer()
token.fit_on_texts(text)
vocab = token.index_word +1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2815ed8a0a59> in <module>
#       1 token = Tokenizer()
#       2 token.fit_on_texts(text)
# ----> 3 vocab = token.index_word +1
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'int'

# %%
encoded_text = token.texts_to_sequences(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f6c71fdb411> in <module>
# ----> 1 encoded_text = token.texts_to_sequences(text)
#
# NameError: name 'token' is not defined

# %%
#pre-process data for ANN
from sklearn.model_selection import train_test_split

df = pd.read_csv('balanced_RNN_data.csv', index_col = 0)
x = df['Reduction text']
y = df['GL']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0, stratify = y)

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
x_train = x_train.reshape(-1, x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(-1, x_test.shape[0], x_test.shape[1], 1)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
#build ANN

hyparam ={'loss':'binary_crossentropy',
         'opt':'Adam',
         'epochs': 10,
         'batch_size':16,
         'validation_data':(X_test, y_test) ,
         'lr':0.001}


model = Sequential()
